# %% [markdown]
# # Step #1: Parse through JSON Flight Log File

# %%
import json
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
import numpy as np

# Enter Flight Log JSON from Fly Catcher BELOW
#selected_file = "./samples/spoofed/aircraft_spoofed.json" 
#selected_file = "./samples/valid/aircraft_valid_small.json" 
selected_file = "./samples/testing/samplecopy.json"

file = open(selected_file)
json_contents = json.load(file)
aircraft = json_contents["aircraft"]

planes = []

class PlaneLog:
    def __init__(self, hex):
        self.hex = hex
        self.planes = []
    def add_plane(self, plane_record):
        self.planes.append(plane_record)

for record in aircraft:
    matched_plane = False
    for plane in planes:
        if plane.hex == record["hex"]:
            plane.add_plane(record)
            matched_plane = True
    if matched_plane == False:
        new_plane = PlaneLog(record["hex"])
        new_plane.add_plane(record)
        planes.append(new_plane)
            
file.close()

print(f"🛫 Detected {len(planes)} planes!")
for i, plane in enumerate(planes):
    print(f"Plane #{i + 1}: {plane.hex} - {len(plane.planes)} records")

def find_plane(hex):
    for plane in planes:
        if plane.hex == hex:
            return plane
# Out:
# 🛫 Detected 20 planes!
# Plane #1: 845f9f - 1 records
# Plane #2: 86d624 - 1 records
# Plane #3: a835c5 - 1 records
# Plane #4: 4d0104 - 1 records
# Plane #5: 86e4da - 1 records
# Plane #6: 71c083 - 1 records
# Plane #7: 76cdb9 - 1 records
# Plane #8: 7c1479 - 1 records
# Plane #9: 86ebb6 - 1 records
# Plane #10: abba6c - 1 records
# Plane #11: 7c531d - 1 records
# Plane #12: ab271f - 1 records
# Plane #13: 8694fa - 1 records
# Plane #14: ADCF46 - 1 records
# Plane #15: B49A8B - 1 records
# Plane #16: B96D38 - 1 records
# Plane #17: E63452 - 1 records
# Plane #18: B9FE57 - 1 records
# Plane #19: 8F79E5 - 1 records
# Plane #20: B0BB00 - 1 records

# %% [markdown]
# # Step 2: Load the CNN Model

# %%
model = tf.keras.models.load_model("Spoof_DetectionV3.keras")
model.summary()
print(model.input_shape, model.output_shape)
def handle_alt_baro(alt_baro):
    if alt_baro == "ground":
        return 0.0
    else:
        return alt_baro

def predict_adsb_data(adsb_message):
    try:
        feature_vector = [
            handle_alt_baro(adsb_message.get('alt_baro', 0)),
            #float(adsb_message.get('alt_baro', 0)),
            float(adsb_message.get('gs', 0)),
            float(adsb_message.get('track', 0)),
            float(adsb_message.get('baro_rate', 0)),
            float(adsb_message.get('lat', 0)),
            float(adsb_message.get('lon', 0)),
            float(adsb_message.get('seen_pos', 0)),
            float(adsb_message.get('messages', 0)),
            float(adsb_message.get('seen', 0)),
            float(adsb_message.get('rssi', 0)),
        ]
    except ValueError as e:
        print(f"Error processing ADS-B message: {adsb_message}, Field: {e}")
        return None

    # scaler = StandardScaler()
    # features_scaled = scaler.fit_transform([feature_vector])
    # prediction = model.predict(np.array(features_scaled))

    prediction = model.predict(np.array([feature_vector]))
    return prediction[0][0]
    #return int(round(prediction[0][0]))
# Out:
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_44 (Dense)                │ (None, 64)             │           704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,221 (36.02 KB)
#  Trainable params: 3,009 (11.75 KB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 6,020 (23.52 KB)
# (None, 10) (None, 1)

# %% [markdown]
# # Step 3: Check if aircraft is spoofed and display on map.

# %%
import folium
from IPython.display import display
m = folium.Map(location = [51.5800, 5.1875], tiles ='OpenStreetMap', zoom_start=3, max_bounds=True, min_zoom=2)

#scaler = StandardScaler()

for plane in planes:
    print(plane.hex)
    aircraft_data = find_plane(plane.hex)
    if aircraft_data == None:
        continue
        
    results = predict_adsb_data(aircraft_data.planes[0])
    print(f'[RESULTS: {results}]')
    spoofed = (True if results > 0.5 else False)
    percentage = results * 100

    text = ("Spoofed" if spoofed else "Not Spoofed")
    print(f"{text} -#-- {percentage}% prediction of being spoofed")
    
    plane_values = [{"key": "hex", "value": "Hex (24-bit ICAO identifier)"}, {"key": "type", "value": "Data Source"}, {"key": "flight", "value": "Flight Callsign"}, {"key": "r", "value": "Aircraft Registration"}, {"key": "t", "value": "Aircraft Type"}, {"key": "alt_baro", "value": "Aircraft Barometric Altitude (feet)"}, {"key": "gs", "value": "Ground Speed (knots)"}, {"key": "track", "value": "True Track (degrees)"}, {"key": "baro_rate", "value": "Rate of Change of Barometric Altitude (feet/minute)"}, {"key": "lat", "value": "Latitude"}, {"key": "lon", "value": "Longitude"}, {"key": "seen_pos", "value": "Updated Time Ago (seconds)"}, {"key": "messages", "value": "Total # of Mode S Messages"}, {"key": "seen", "value": "Last Timing Message (seconds)"}, {"key": "rssi", "value": "Signal Power (dbFs)"}]
    
    def find_value(id):
        for x in plane_values:
            if x["key"] == id:
                return x

    plane_data = aircraft_data.planes[0]
    plane_coordinates = (plane_data["lat"], plane_data["lon"])

    # Draw map markers
    folium.CircleMarker(
        location=plane_coordinates,
        radius=5,
        color=("red" if spoofed else "green"),
        fill=True,
        fill_color=("red" if spoofed else "green"),
        fill_opacity=0.7,
        popup='Flight: ' + aircraft_data.planes[0]['flight'] + '<br>Hex: ' + plane.hex + '<br>Lat: ' + str(aircraft_data.planes[0]['lat']) + '<br>Lon: ' + str(aircraft_data.planes[0]['lon'])
    ).add_to(m)

display(m)
# Out:
# 845f9f
# WARNING:tensorflow:5 out of the last 28 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000019CC16813A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# [RESULTS: -228995.109375]
# Not Spoofed -#-- -22899510.0% prediction of being spoofed
# 86d624
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [RESULTS: -140789.390625]
# Not Spoofed -#-- -14078939.0% prediction of being spoofed
# a835c5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [RESULTS: -256560.71875]
# Not Spoofed -#-- -25656072.0% prediction of being spoofed
# 4d0104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [RESULTS: -356171.15625]
# Not Spoofed -#-- -35617116.0% prediction of being spoofed
# 86e4da
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [RESULTS: -175618.703125]
# Not Spoofed -#-- -17561870.0% prediction of being spoofed
# 71c083
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [RESULTS: -221635.046875]
# Not Spoofed -#-- -22163504.0% prediction of being spoofed
# 76cdb9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [RESULTS: -195319.921875]
# Not Spoofed -#-- -19531992.0% prediction of being spoofed
# 7c1479
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [RESULTS: -145454.34375]
# Not Spoofed -#-- -14545434.0% prediction of being spoofed
# 86ebb6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [RESULTS: -111842.2265625]
# Not Spoofed -#-- -11184223.0% prediction of being spoofed
# abba6c
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [RESULTS: -252445.9375]
# Not Spoofed -#-- -25244594.0% prediction of being spoofed
# 7c531d
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [RESULTS: -174877.734375]
# Not Spoofed -#-- -17487774.0% prediction of being spoofed
# ab271f
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [RESULTS: -284630.0625]
# Not Spoofed -#-- -28463006.0% prediction of being spoofed
# 8694fa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [RESULTS: -216755.28125]
# Not Spoofed -#-- -21675528.0% prediction of being spoofed
# ADCF46
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [RESULTS: 4337.71044921875]
# Spoofed -#-- 433771.03125% prediction of being spoofed
# B49A8B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [RESULTS: 8964.4365234375]
# Spoofed -#-- 896443.625% prediction of being spoofed
# B96D38
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [RESULTS: 5666.5322265625]
# Spoofed -#-- 566653.25% prediction of being spoofed
# E63452
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [RESULTS: 10554.990234375]
# Spoofed -#-- 1055499.0% prediction of being spoofed
# B9FE57
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [RESULTS: 10279.431640625]
# Spoofed -#-- 1027943.1875% prediction of being spoofed
# 8F79E5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [RESULTS: 5274.671875]
# Spoofed -#-- 527467.1875% prediction of being spoofed
# B0BB00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [RESULTS: 5850.90087890625]
# Spoofed -#-- 585090.0625% prediction of being spoofed
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad42e63977f09c65c193aad44b3a8e15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad42e63977f09c65c193aad44b3a8e15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad42e63977f09c65c193aad44b3a8e15 = L.map(
#                 &quot;map_ad42e63977f09c65c193aad44b3a8e15&quot;,
#                 {
#                     center: [51.58, 5.1875],
#                     crs: L.CRS.EPSG3857,
#                     maxBounds: [[-90, -180], [90, 180]],
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cddc5467ba7d42f54c882e2f15b87c5c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 2, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cddc5467ba7d42f54c882e2f15b87c5c.addTo(map_ad42e63977f09c65c193aad44b3a8e15);
#
#
#             var circle_marker_d97ccb8b8bb9bd80fdf776d0030e0352 = L.circleMarker(
#                 [57.32872, -177.562752],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ad42e63977f09c65c193aad44b3a8e15);
#
#
#         var popup_d628b17649ab8977eb887bf4a9ac8e78 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16d5a7ba86f4d6d1bfedb2e037b33ffb = $(`&lt;div id=&quot;html_16d5a7ba86f4d6d1bfedb2e037b33ffb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Flight: KZ51    &lt;br&gt;Hex: 845f9f&lt;br&gt;Lat: 57.32872&lt;br&gt;Lon: -177.562752&lt;/div&gt;`)[0];
#                 popup_d628b17649ab8977eb887bf4a9ac8e78.setContent(html_16d5a7ba86f4d6d1bfedb2e037b33ffb);
#
#
#
#         circle_marker_d97ccb8b8bb9bd80fdf776d0030e0352.bindPopup(popup_d628b17649ab8977eb887bf4a9ac8e78)
#         ;
#
#
#
#
#             var circle_marker_a4cf5a3a2271879f97d692898c8611cf = L.circleMarker(
#                 [56.712799, -176.982708],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ad42e63977f09c65c193aad44b3a8e15);
#
#
#         var popup_23c9075a5e4d19180f32a7a375008909 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c636796de29e66f03eaa47507a27696 = $(`&lt;div id=&quot;html_4c636796de29e66f03eaa47507a27696&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Flight: ZG23    &lt;br&gt;Hex: 86d624&lt;br&gt;Lat: 56.712799&lt;br&gt;Lon: -176.982708&lt;/div&gt;`)[0];
#                 popup_23c9075a5e4d19180f32a7a375008909.setContent(html_4c636796de29e66f03eaa47507a27696);
#
#
#
#         circle_marker_a4cf5a3a2271879f97d692898c8611cf.bindPopup(popup_23c9075a5e4d19180f32a7a375008909)
#         ;
#
#
#
#
#             var circle_marker_cf2b13c1db1e9bdbc6ad1cbc1ec610e0 = L.circleMarker(
#                 [2.205334, -174.191151],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ad42e63977f09c65c193aad44b3a8e15);
#
#
#         var popup_92d1a5f08805c784509335e362daeefd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_15237683c23fa0bced2fb02a891b87a1 = $(`&lt;div id=&quot;html_15237683c23fa0bced2fb02a891b87a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Flight: UP34    &lt;br&gt;Hex: a835c5&lt;br&gt;Lat: 2.205334&lt;br&gt;Lon: -174.191151&lt;/div&gt;`)[0];
#                 popup_92d1a5f08805c784509335e362daeefd.setContent(html_15237683c23fa0bced2fb02a891b87a1);
#
#
#
#         circle_marker_cf2b13c1db1e9bdbc6ad1cbc1ec610e0.bindPopup(popup_92d1a5f08805c784509335e362daeefd)
#         ;
#
#
#
#
#             var circle_marker_ea27bf9e0fbcaa9468ae54970c0b57f1 = L.circleMarker(
