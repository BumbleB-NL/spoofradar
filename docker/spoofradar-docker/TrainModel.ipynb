# %%
import json 
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import random

# Valid data parsing first
with open('./samples/valid/aircraft_valid.json') as json_file:
    data_valid = json.load(json_file)
print(data_valid['aircraft'][0])
print("Valid count: ", len(data_valid['aircraft']))
# Parse spoofed data
with open('./samples/spoofed/aircraft_spoofed_large.json') as json_file:
    data_spoofed = json.load(json_file)
    
aircraft_data_valid = data_valid['aircraft']
aircraft_data_spoofed = data_spoofed['aircraft']

np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

print("Datasets imported!")
# Out:
# {'hex': '845f9f', 'type': 'adsc', 'flight': 'KZ51    ', 'r': 'JA11KZ', 't': 'B748', 'alt_baro': 31996, 'gs': 487.0, 'track': 244.0, 'baro_rate': 48, 'lat': 57.32872, 'lon': -177.562752, 'nic': 0, 'rc': 0, 'seen_pos': 873.399, 'mlat': [], 'tisb': [], 'messages': 4420465, 'seen': 803.5, 'rssi': -29.2}
# Valid count:  8423
# Datasets imported!

# %%
# Define a function to preprocess the data
def preprocess_data(data):
    features = []
    labels = []

    for aircraft in data:
        try:
            feature_vector = [
                #alt_baro maybe float?
                handle_alt_baro(aircraft.get('alt_baro', 0)),
                float(aircraft.get('gs', 0)),
                float(aircraft.get('track', 0)),
                float(aircraft.get('baro_rate', 0)),
                float(aircraft.get('lat', 0)),
                float(aircraft.get('lon', 0)),
                float(aircraft.get('seen_pos', 0)),
                float(aircraft.get('messages', 0)),
                float(aircraft.get('seen', 0)),
                float(aircraft.get('rssi', 0)),
            ]
            features.append(feature_vector)
            labels.append(1 if aircraft.get('is_spoofed', False) else 0)
        except ValueError as e:
            # Handle the case where a non-numeric value is encountered
            print(f"Ignoring data point due to non-numeric value: {aircraft}, Field {e}")

    #return np.array(features), np.array(labels)
    features = np.array(features)
    labels = np.array(labels)

    # # Scale features
    scaler = StandardScaler()
    features = scaler.fit_transform(features)

    return features, labels

def handle_alt_baro(alt_baro):
    if alt_baro == "ground":
        return 0.0
    else:
        return alt_baro
    
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(10,)),  # Define input shape explicitly
    
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    
    tf.keras.layers.Dense(1, activation='sigmoid')
])


# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,201 (12.50 KB)
#  Trainable params: 3,009 (11.75 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
spoofed_features, spoofed_labels = preprocess_data(aircraft_data_spoofed)
not_spoofed_features, not_spoofed_labels = preprocess_data(aircraft_data_valid)

# Combine the data
all_features = np.vstack([spoofed_features, not_spoofed_features])
all_labels = np.concatenate([spoofed_labels, not_spoofed_labels])

print(all_features, all_labels)
# Out:
# [[ 1.21698152  0.12338133  0.30270961 ...  1.3314093   0.79770954
#    1.07453948]
#  [ 0.41029097  0.62593615  0.55088812 ...  0.39182697 -1.23409194
#   -0.62562485]
#  [-1.15802799  1.48547818 -1.42499466 ... -1.5802634   0.72848291
#    0.23125797]
#  ...
#  [-1.10993969 -1.32685152 -1.21581286 ... -1.17306362  0.07194092
#   -1.81647978]
#  [-1.10993969 -1.32685152 -1.21581286 ... -0.10443824  0.02871073
#    0.06106721]
#  [-1.10993969 -1.32685152 -1.21581286 ...  0.62940328 -0.11199928
#    1.19022134]] [1 1 1 ... 0 0 0]

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(all_features, all_labels, test_size=0.2, random_state=42)

# Train the model !!! ADDED CLASS_WEIGHT, MIGHT NOT BE NEEDED
#class_weight={0: 1., 1: 10.}
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5215 - loss: 0.8745 - val_accuracy: 0.6735 - val_loss: 0.6385
# Epoch 2/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - accuracy: 0.5954 - loss: 0.7324 - val_accuracy: 0.7641 - val_loss: 0.5513
# Epoch 3/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 0.6540 - loss: 0.6413 - val_accuracy: 0.8158 - val_loss: 0.4995
# Epoch 4/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7009 - loss: 0.5879 - val_accuracy: 0.8336 - val_loss: 0.4593
# Epoch 5/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7221 - loss: 0.5607 - val_accuracy: 0.8496 - val_loss: 0.4260
# Epoch 6/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7548 - loss: 0.5138 - val_accuracy: 0.8640 - val_loss: 0.3954
# Epoch 7/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7735 - loss: 0.4859 - val_accuracy: 0.8778 - val_loss: 0.3682
# Epoch 8/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.7960 - loss: 0.4523 - val_accuracy: 0.8930 - val_loss: 0.3403
# Epoch 9/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.8173 - loss: 0.4150 - val_accuracy: 0.8978 - val_loss: 0.3170
# Epoch 10/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.8278 - loss: 0.3969 - val_accuracy: 0.9056 - val_loss: 0.2949
# Epoch 11/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - accuracy: 0.8418 - loss: 0.3700 - val_accuracy: 0.9123 - val_loss: 0.2732
# Epoch 12/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8540 - loss: 0.3465 - val_accuracy: 0.9168 - val_loss: 0.2535
# Epoch 13/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.8716 - loss: 0.3171 - val_accuracy: 0.9253 - val_loss: 0.2357
# Epoch 14/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.8739 - loss: 0.3058 - val_accuracy: 0.9302 - val_loss: 0.2204
# Epoch 15/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 0.8970 - loss: 0.2687 - val_accuracy: 0.9339 - val_loss: 0.2052
# Epoch 16/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.8990 - loss: 0.2596 - val_accuracy: 0.9380 - val_loss: 0.1911
# Epoch 17/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 0.9083 - loss: 0.2430 - val_accuracy: 0.9435 - val_loss: 0.1782
# Epoch 18/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.9093 - loss: 0.2370 - val_accuracy: 0.9495 - val_loss: 0.1659
# Epoch 19/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - accuracy: 0.9223 - loss: 0.2049 - val_accuracy: 0.9506 - val_loss: 0.1558
# Epoch 20/20
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9288 - loss: 0.1940 - val_accuracy: 0.9517 - val_loss: 0.1456
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.9680 - loss: 0.1139
# Test accuracy: 0.9664190411567688

# %%
model_name = "ModelTestV4.keras"
model.save(model_name)
print(f"Model saved to {model_name}!")
# Out:
# Model saved to ModelTestV4.keras!

# %%
import json
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
import numpy as np
import folium

selected_file = "./samples/testing/sample_custom.json"

file = open(selected_file)
json_contents = json.load(file)
aircraft = json_contents["aircraft"]

planes = []

class PlaneLog:
    def __init__(self, hex):
        self.hex = hex
        self.planes = []
    def add_plane(self, plane_record):
        self.planes.append(plane_record)

for record in aircraft:
    matched_plane = False
    for plane in planes:
        if plane.hex == record["hex"]:
            plane.add_plane(record)
            matched_plane = True
    if matched_plane == False:
        new_plane = PlaneLog(record["hex"])
        new_plane.add_plane(record)
        planes.append(new_plane)
            
file.close()

print(f"🛫 Detected {len(planes)} planes!")
for i, plane in enumerate(planes):
    print(f"Plane #{i + 1}: {plane.hex} - {len(plane.planes)} records")

def find_plane(hex):
    for plane in planes:
        if plane.hex == hex:
            return plane
        
model = tf.keras.models.load_model("ModelTestV4.keras")
model.summary()
print(model.input_shape, model.output_shape)
def handle_alt_baro(alt_baro):
    if alt_baro == "ground":
        return 0.0
    else:
        return alt_baro

def predict_adsb_data(adsb_message):
    try:
        feature_vector = [
            handle_alt_baro(adsb_message.get('alt_baro', 0)),
            #float(adsb_message.get('alt_baro', 0)),
            float(adsb_message.get('gs', 0)),
            float(adsb_message.get('track', 0)),
            float(adsb_message.get('baro_rate', 0)),
            float(adsb_message.get('lat', 0)),
            float(adsb_message.get('lon', 0)),
            float(adsb_message.get('seen_pos', 0)),
            float(adsb_message.get('messages', 0)),
            float(adsb_message.get('seen', 0)),
            float(adsb_message.get('rssi', 0)),
        ]
    except ValueError as e:
        print(f"Error processing ADS-B message: {adsb_message}, Field: {e}")
        return None

    # scaler = StandardScaler()
    # features_scaled = scaler.fit_transform([feature_vector])
    # prediction = model.predict(np.array(features_scaled))

    prediction = model.predict(np.array([feature_vector]))
    print(prediction[:10])
    return prediction[0][0]
    #return int(round(prediction[0][0]))
    
from IPython.display import display
m = folium.Map(location = [51.5800, 5.1875], tiles ='OpenStreetMap', zoom_start=3, max_bounds=True, min_zoom=2)

#scaler = StandardScaler()

for plane in planes:
    #print(plane.hex)
    aircraft_data = find_plane(plane.hex)
    if aircraft_data == None:
        continue
        
    results = predict_adsb_data(aircraft_data.planes[0])
    #print(f'[RESULTS: {results}]')
    spoofed = (True if results > 0.5 else False)
    percentage = results * 100

    text = ("Spoofed" if spoofed else "Not Spoofed")
    #print(f"{text} -#-- {percentage}% prediction of being spoofed")
    
    plane_values = [{"key": "hex", "value": "Hex (24-bit ICAO identifier)"}, {"key": "type", "value": "Data Source"}, {"key": "flight", "value": "Flight Callsign"}, {"key": "r", "value": "Aircraft Registration"}, {"key": "t", "value": "Aircraft Type"}, {"key": "alt_baro", "value": "Aircraft Barometric Altitude (feet)"}, {"key": "gs", "value": "Ground Speed (knots)"}, {"key": "track", "value": "True Track (degrees)"}, {"key": "baro_rate", "value": "Rate of Change of Barometric Altitude (feet/minute)"}, {"key": "lat", "value": "Latitude"}, {"key": "lon", "value": "Longitude"}, {"key": "seen_pos", "value": "Updated Time Ago (seconds)"}, {"key": "messages", "value": "Total # of Mode S Messages"}, {"key": "seen", "value": "Last Timing Message (seconds)"}, {"key": "rssi", "value": "Signal Power (dbFs)"}]
    
    def find_value(id):
        for x in plane_values:
            if x["key"] == id:
                return x

    plane_data = aircraft_data.planes[0]
    plane_coordinates = (plane_data["lat"], plane_data["lon"])

    # Draw map markers
    folium.CircleMarker(
        location=plane_coordinates,
        radius=5,
        color=("red" if spoofed else "green"),
        fill=True,
        fill_color=("red" if spoofed else "green"),
        fill_opacity=0.7,
        popup='<br>Hex: ' + plane.hex + '<br>Lat: ' + str(aircraft_data.planes[0]['lat']) + '<br>Lon: ' + str(aircraft_data.planes[0]['lon'])
    ).add_to(m)

display(m)
# Out:
# 🛫 Detected 124 planes!
# Plane #1: 3C4D61 - 1 records
# Plane #2: 4D5E21 - 1 records
# Plane #3: 5D6F31 - 1 records
# Plane #4: 6F7F12 - 1 records
# Plane #5: 7F8D34 - 1 records
# Plane #6: 8E9A54 - 1 records
# Plane #7: 9C2B65 - 1 records
# Plane #8: 1A1B76 - 1 records
# Plane #9: 2B4C87 - 1 records
# Plane #10: 3C5D98 - 1 records
# Plane #11: 4D6E09 - 1 records
# Plane #12: 5E7F20 - 1 records
# Plane #13: 6F8D41 - 1 records
# Plane #14: 7E9C52 - 1 records
# Plane #15: 8F0D63 - 1 records
# Plane #16: 9E3F74 - 1 records
# Plane #17: 1A4B85 - 1 records
# Plane #18: 2B5C96 - 1 records
# Plane #19: 3D6D07 - 1 records
# Plane #20: abd6c6 - 1 records
# Plane #21: 869560 - 1 records
# Plane #22: a60b1e - 1 records
# Plane #23: 86e79a - 1 records
# Plane #24: 383E36 - 1 records
# Plane #25: a4c79b - 1 records
# Plane #26: 71c011 - 1 records
# Plane #27: 78072a - 1 records
# Plane #28: aa5bc5 - 1 records
# Plane #29: aa8499 - 1 records
# Plane #30: a1c7e4 - 1 records
# Plane #31: adb4f0 - 1 records
# Plane #32: a973be - 1 records
# Plane #33: acebbe - 1 records
# Plane #34: c02ec7 - 1 records
# Plane #35: 86cf16 - 1 records
# Plane #36: 86e40e - 1 records
# Plane #37: a54847 - 1 records
# Plane #38: 71c393 - 1 records
# Plane #39: 71be33 - 1 records
# Plane #40: a1b157 - 1 records
# Plane #41: a828e1 - 1 records
# Plane #42: a4c74c - 1 records
# Plane #43: adc50d - 1 records
# Plane #44: aae22e - 1 records
# Plane #45: a97128 - 1 records
# Plane #46: a4db4e - 1 records
# Plane #47: a2f2fa - 1 records
# Plane #48: 8990ee - 1 records
# Plane #49: 872f7e - 1 records
# Plane #50: a96412 - 1 records
# Plane #51: a980b9 - 1 records
# Plane #52: a581c8 - 1 records
# Plane #53: a67191 - 1 records
# Plane #54: c01a61 - 1 records
# Plane #55: a02b39 - 1 records
# Plane #56: ad68dc - 1 records
# Plane #57: a5d45d - 1 records
# Plane #58: a535be - 1 records
# Plane #59: ae10e8 - 1 records
# Plane #60: a1e5be - 1 records
# Plane #61: 71c042 - 1 records
# Plane #62: ac7854 - 1 records
# Plane #63: a19a21 - 1 records
# Plane #64: a61836 - 1 records
# Plane #65: a515ad - 1 records
# Plane #66: a43fa0 - 1 records
# Plane #67: a12557 - 1 records
# Plane #68: a51d83 - 1 records
# Plane #69: ab71d4 - 1 records
# Plane #70: a24efd - 1 records
# Plane #71: ab5d52 - 1 records
# Plane #72: a43e0e - 1 records
# Plane #73: ac90de - 1 records
# Plane #74: ae567b - 1 records
# Plane #75: ae52df - 1 records
# Plane #76: a9eec4 - 1 records
# Plane #77: a0717a - 1 records
# Plane #78: a60701 - 1 records
# Plane #79: ac101f - 1 records
# Plane #80: ac04d3 - 1 records
# Plane #81: ~300c13 - 1 records
# Plane #82: ~3006aa - 1 records
# Plane #83: ~300dd5 - 1 records
# Plane #84: a47244 - 1 records
# Plane #85: ~300862 - 1 records
# Plane #86: a6235b - 1 records
# Plane #87: a07e79 - 1 records
# Plane #88: a28334 - 1 records
# Plane #89: a5f61d - 1 records
# Plane #90: ~300e4e - 1 records
# Plane #91: a61159 - 1 records
# Plane #92: ac08b1 - 1 records
# Plane #93: ~3001af - 1 records
# Plane #94: ~300c0b - 1 records
# Plane #95: 86e86e - 1 records
# Plane #96: ad9e28 - 1 records
# Plane #97: ~300341 - 1 records
# Plane #98: ~3002b4 - 1 records
# Plane #99: abcf58 - 1 records
# Plane #100: ~300456 - 1 records
# Plane #101: ~300689 - 1 records
# Plane #102: ~3005bc - 1 records
# Plane #103: ~30067a - 1 records
# Plane #104: ~300cca - 1 records
# Plane #105: aa64ba - 1 records
# Plane #106: a1befc - 1 records
# Plane #107: ~300929 - 1 records
# Plane #108: ~30081c - 1 records
# Plane #109: 4076e5 - 1 records
# Plane #110: a9d376 - 1 records
# Plane #111: ad8857 - 1 records
# Plane #112: abbeb6 - 1 records
# Plane #113: ~300fc1 - 1 records
# Plane #114: ~300b5f - 1 records
# Plane #115: a02b3b - 1 records
# Plane #116: 729879 - 1 records
# Plane #117: 5C8413 - 1 records
# Plane #118: 24D137 - 1 records
# Plane #119: 0F72EC - 1 records
# Plane #120: 5FB2FE - 1 records
# Plane #121: 066205 - 1 records
# Plane #122: 4B6C0A - 1 records
# Plane #123: A48523 - 1 records
# Plane #124: 730D19 - 1 records
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,221 (36.02 KB)
#  Trainable params: 3,009 (11.75 KB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 6,020 (23.52 KB)
# (None, 10) (None, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[7.002285e-21]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[1.3323177e-35]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[8.012175e-17]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# [[1.]]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_efe37bbe09d4c98ad6802ae31da531d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_efe37bbe09d4c98ad6802ae31da531d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_efe37bbe09d4c98ad6802ae31da531d9 = L.map(
#                 &quot;map_efe37bbe09d4c98ad6802ae31da531d9&quot;,
#                 {
#                     center: [51.58, 5.1875],
#                     crs: L.CRS.EPSG3857,
#                     maxBounds: [[-90, -180], [90, 180]],
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f5b2476726ab54aabc3c1d0694d1803c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 2, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f5b2476726ab54aabc3c1d0694d1803c.addTo(map_efe37bbe09d4c98ad6802ae31da531d9);
#
#
#             var circle_marker_7e27f653405f4cfb8149ea5e37a89f46 = L.circleMarker(
#                 [52.3081, 4.7631],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_efe37bbe09d4c98ad6802ae31da531d9);
#
#
#         var popup_c177b3c68061d6c3e4d01da375eccb2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b656d8a25d7010bb3fedb89dcbcbf0bd = $(`&lt;div id=&quot;html_b656d8a25d7010bb3fedb89dcbcbf0bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;br&gt;Hex: 3C4D61&lt;br&gt;Lat: 52.3081&lt;br&gt;Lon: 4.7631&lt;/div&gt;`)[0];
#                 popup_c177b3c68061d6c3e4d01da375eccb2e.setContent(html_b656d8a25d7010bb3fedb89dcbcbf0bd);
#
#
#
#         circle_marker_7e27f653405f4cfb8149ea5e37a89f46.bindPopup(popup_c177b3c68061d6c3e4d01da375eccb2e)
#         ;
#
#
#
#
#             var circle_marker_024b27416e6fe1caaa5970ffd34917f9 = L.circleMarker(
#                 [52.503, 5.2072],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_efe37bbe09d4c98ad6802ae31da531d9);
#
#
#         var popup_2f5e250e7bfc235409dea4c680079cc2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd222c47562db788b131f3323d959c8c = $(`&lt;div id=&quot;html_bd222c47562db788b131f3323d959c8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;br&gt;Hex: 4D5E21&lt;br&gt;Lat: 52.503&lt;br&gt;Lon: 5.2072&lt;/div&gt;`)[0];
#                 popup_2f5e250e7bfc235409dea4c680079cc2.setContent(html_bd222c47562db788b131f3323d959c8c);
#
#
#
#         circle_marker_024b27416e6fe1caaa5970ffd34917f9.bindPopup(popup_2f5e250e7bfc235409dea4c680079cc2)
#         ;
#
#
#
#
#             var circle_marker_d16e3726b0cb108c49382b03883aae6f = L.circleMarker(
#                 [51.976, 4.8501],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_efe37bbe09d4c98ad6802ae31da531d9);
#
#
#         var popup_e7c70ea05d678863251586e52f334e43 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa3b27c568edcd99da1fe1fc0089590c = $(`&lt;div id=&quot;html_fa3b27c568edcd99da1fe1fc0089590c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;br&gt;Hex: 5D6F31&lt;br&gt;Lat: 51.976&lt;br&gt;Lon: 4.8501&lt;/div&gt;`)[0];
#                 popup_e7c70ea05d678863251586e52f334e43.setContent(html_fa3b27c568edcd99da1fe1fc0089590c);
#
#
#
#         circle_marker_d16e3726b0cb108c49382b03883aae6f.bindPopup(popup_e7c70ea05d678863251586e52f334e43)
#         ;
#
#
#
#
#             var circle_marker_7c99e0bec4e480fe2089c017d15ec5ab = L.circleMarker(
#                 [53.342, 6.7365],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color
